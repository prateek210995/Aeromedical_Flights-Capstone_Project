# %%
#load packages
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 999)

# %%
fw = pd.read_csv("../Datasets/NEW/FW_with_airports.csv", parse_dates=['date'])

# %%
fw = fw.iloc[:,:11].join(fw.iloc[:,-1])

# %%
fw.head()
# Out:
#   tail_number       date aircraft origin_code  \
# 0      N100KB 2021-02-20     BE9L     US-0571
# 1      N100KB 2021-02-20     BE9L        KBIS
# 2      N100KB 2021-02-18     BE9L        KMOT
# 3      N100KB 2021-02-15     BE9L     US-0571
# 4      N100KB 2021-02-15     BE9L        KMOT
#
#                                          origin destination_code  \
# 0  Williston Basin International Airport (KXWA)             KBIS
# 1                          Bismarck Muni (KBIS)          US-0571
# 2                             Minot Intl (KMOT)             KBIS
# 3  Williston Basin International Airport (KXWA)             KMOT
# 4                             Minot Intl (KMOT)          US-0571
#
#                                     destination    departure      arrival  \
# 0                          Bismarck Muni (KBIS)  04:57PM CST  05:44PM CST
# 1  Williston Basin International Airport (KXWA)  01:36PM CST  02:27PM CST
# 2                          Bismarck Muni (KBIS)  08:20AM CST  08:53AM CST
# 3                             Minot Intl (KMOT)  02:15PM CST  02:49PM CST
# 4  Williston Basin International Airport (KXWA)  08:00AM CST  08:32AM CST
#
#   duration  distance_mi                                              Owner
# 0     0:46   174.005874  EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpor...
# 1     0:51   174.005874  EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpor...
# 2     0:32   105.704153  EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpor...
# 3     0:33   113.899460  EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpor...
# 4     0:32   113.899460  EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpor...

# %%
fw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23160 entries, 0 to 23159
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tail_number       23160 non-null  object
#  1   date              23160 non-null  datetime64[ns]
#  2   aircraft          22966 non-null  object
#  3   origin_code       23142 non-null  object
#  4   origin            23160 non-null  object
#  5   destination_code  23121 non-null  object
#  6   destination       23159 non-null  object
#  7   departure         23160 non-null  object
#  8   arrival           22730 non-null  object
#  9   duration          22680 non-null  object
#  10  distance_mi       23151 non-null  float64
#  11  Owner             23160 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(10)
# memory usage: 2.1+ MB

# %%
fw.isna().sum()
# Out:
# tail_number           0
# date                  0
# aircraft            194
# origin_code          18
# origin                0
# destination_code     39
# destination           1
# departure             0
# arrival             430
# duration            480
# distance_mi           9
# Owner                 0
# dtype: int64

# %%
# exclude all diverted and practice flights 
fw = fw.loc[(fw.origin != fw.destination) & (fw.arrival.notnull()) & (fw.destination.notnull()) & (fw.duration.notnull())
           & (fw.distance_mi.notnull())]

# %%
# convert duration to minutes and add a new column 
fw['duration_minutes'] = pd.to_datetime(fw.duration, format="%H:%M", errors='coerce').dt.hour * 60 + pd.to_datetime(fw.duration, format="%H:%M",errors='coerce').dt.minute

# %%
# exclude all flight less that 2 minutes. We cansider that as diverted or canceled 
fw = fw.loc[fw.duration_minutes > 2]

# %%
# set Owner and tail_number as indices
fw = fw.set_index(['Owner', 'tail_number'])

# %%
# calculate 25 quantile of each tail number of the airmedical service
fw['duration_q_25'] = fw.groupby(['Owner', 'tail_number']).duration_minutes.quantile(0.25)

# calculate 75 quantile of each tail number of the airmedical service
fw['duration_q_75'] = fw.groupby(['Owner', 'tail_number']).duration_minutes.quantile(0.75)

# calculate IQR
fw['duration_iqr'] = fw['duration_q_75'] - fw['duration_q_25']

# calculate lower whisker
fw['duration_lower_whisker'] = fw['duration_q_25'] - (1.5 * fw['duration_iqr'])

# calculate upper whisker
fw['duration_upper_whisker'] = fw['duration_q_75'] + (1.5 * fw['duration_iqr'])

# %%
fw['duration_outlier'] = np.where((fw.duration_minutes < fw.duration_lower_whisker) | (fw.duration_minutes > fw.duration_upper_whisker), "Yes", "No")

# %%
# calculate 25 quantile of each tail number of the airmedical service
fw['distance_q_25'] = fw.groupby(['Owner', 'tail_number']).distance_mi.quantile(0.25)

# calculate 75 quantile of each tail number of the airmedical service
fw['distance_q_75'] = fw.groupby(['Owner', 'tail_number']).distance_mi.quantile(0.75)

# calculate IQR
fw['distance_iqr'] = fw['distance_q_75'] - fw['distance_q_25']

# calculate lower whisker
fw['distance_lower_whisker'] = fw['distance_q_25'] - (1.5 * fw['distance_iqr'])

# calculate upper whisker
fw['distance_upper_whisker'] = fw['distance_q_75'] + (1.5 * fw['distance_iqr'])

# %%
fw['distance_outlier'] = np.where((fw.distance_mi < fw.distance_lower_whisker) | (fw.distance_mi > fw.distance_upper_whisker), "Yes", "No")

# %%
fw.head()
# Out:
#                                                                      date  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB      2021-02-20
#                                                    N100KB      2021-02-20
#                                                    N100KB      2021-02-18
#                                                    N100KB      2021-02-15
#                                                    N100KB      2021-02-15
#
#                                                                aircraft  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB          BE9L
#                                                    N100KB          BE9L
#                                                    N100KB          BE9L
#                                                    N100KB          BE9L
#                                                    N100KB          BE9L
#
#                                                                origin_code  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB          US-0571
#                                                    N100KB             KBIS
#                                                    N100KB             KMOT
#                                                    N100KB          US-0571
#                                                    N100KB             KMOT
#
#                                                                                                       origin  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB       Williston Basin International Airport (KXWA)
#                                                    N100KB                               Bismarck Muni (KBIS)
#                                                    N100KB                                  Minot Intl (KMOT)
#                                                    N100KB       Williston Basin International Airport (KXWA)
#                                                    N100KB                                  Minot Intl (KMOT)
#
#                                                                destination_code  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB                  KBIS
#                                                    N100KB               US-0571
#                                                    N100KB                  KBIS
#                                                    N100KB                  KMOT
#                                                    N100KB               US-0571
#
#                                                                                                  destination  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB                               Bismarck Muni (KBIS)
#                                                    N100KB       Williston Basin International Airport (KXWA)
#                                                    N100KB                               Bismarck Muni (KBIS)
#                                                    N100KB                                  Minot Intl (KMOT)
#                                                    N100KB       Williston Basin International Airport (KXWA)
#
#                                                                   departure  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB       04:57PM CST
#                                                    N100KB       01:36PM CST
#                                                    N100KB       08:20AM CST
#                                                    N100KB       02:15PM CST
#                                                    N100KB       08:00AM CST
#
#                                                                     arrival  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB       05:44PM CST
#                                                    N100KB       02:27PM CST
#                                                    N100KB       08:53AM CST
#                                                    N100KB       02:49PM CST
#                                                    N100KB       08:32AM CST
#
#                                                                duration  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB          0:46
#                                                    N100KB          0:51
#                                                    N100KB          0:32
#                                                    N100KB          0:33
#                                                    N100KB          0:32
#
#                                                                 distance_mi  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB        174.005874
#                                                    N100KB        174.005874
#                                                    N100KB        105.704153
#                                                    N100KB        113.899460
#                                                    N100KB        113.899460
#
#                                                                 duration_minutes  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB                     46
#                                                    N100KB                     51
#                                                    N100KB                     32
#                                                    N100KB                     33
#                                                    N100KB                     32
#
#                                                                 duration_q_25  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB                32.5
#                                                    N100KB                32.5
#                                                    N100KB                32.5
#                                                    N100KB                32.5
#                                                    N100KB                32.5
#
#                                                                 duration_q_75  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB                78.0
#                                                    N100KB                78.0
#                                                    N100KB                78.0
#                                                    N100KB                78.0
#                                                    N100KB                78.0
#
#                                                                 duration_iqr  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB               45.5
#                                                    N100KB               45.5
#                                                    N100KB               45.5
#                                                    N100KB               45.5
#                                                    N100KB               45.5
#
#                                                                 duration_lower_whisker  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB                       -35.75
#                                                    N100KB                       -35.75
#                                                    N100KB                       -35.75
#                                                    N100KB                       -35.75
#                                                    N100KB                       -35.75
#
#                                                                 duration_upper_whisker  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB                       146.25
#                                                    N100KB                       146.25
#                                                    N100KB                       146.25
#                                                    N100KB                       146.25
#                                                    N100KB                       146.25
#
#                                                                duration_outlier  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB                    No
#                                                    N100KB                    No
#                                                    N100KB                    No
#                                                    N100KB                    No
#                                                    N100KB                    No
#
#                                                                 distance_q_25  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB          111.954264
#                                                    N100KB          111.954264
#                                                    N100KB          111.954264
#                                                    N100KB          111.954264
#                                                    N100KB          111.954264
#
#                                                                 distance_q_75  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB           244.59526
#                                                    N100KB           244.59526
#                                                    N100KB           244.59526
#                                                    N100KB           244.59526
#                                                    N100KB           244.59526
#
#                                                                 distance_iqr  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB         132.640996
#                                                    N100KB         132.640996
#                                                    N100KB         132.640996
#                                                    N100KB         132.640996
#                                                    N100KB         132.640996
#
#                                                                 distance_lower_whisker  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB                    -87.00723
#                                                    N100KB                    -87.00723
#                                                    N100KB                    -87.00723
#                                                    N100KB                    -87.00723
#                                                    N100KB                    -87.00723
#
#                                                                 distance_upper_whisker  \
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB                   443.556754
#                                                    N100KB                   443.556754
#                                                    N100KB                   443.556754
#                                                    N100KB                   443.556754
#                                                    N100KB                   443.556754
#
#                                                                distance_outlier
# Owner                                              tail_number
# EXECUTIVE AIR TAXI CORPBISMARCK, ND, US(Corpora... N100KB                    No
#                                                    N100KB                    No
#                                                    N100KB                    No
#                                                    N100KB                    No
#                                                    N100KB                    No

# %%
fw.to_csv('..//Datasets/NEW/FW_Outliers.csv')
