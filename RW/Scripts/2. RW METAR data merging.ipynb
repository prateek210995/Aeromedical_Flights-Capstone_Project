# %%
import os
import sys
import pandas as pd
import numpy as np
sys.path.append(os.getcwd() + '/Modules/')
from utc_converter import utc_converter
from metar_decoder import metar_decoder
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Data preprocessing
# ---

# %%
# load data frame
rw = pd.read_csv("..//Datasets/NEW/RW_with_airports.csv")

# %%
# add time with UTC format 
rw = utc_converter(rw)

# %%
rw.head()
# Out:
#   tail_number     date aircraft origin_code                          origin  \
# 0      N640EC  3/11/21     EC35        KPGV          Pitt-Greenville (KPGV)
# 1      N640EC  3/11/21     EC35        KRWI  Rocky Mount-Wilson Rgnl (KRWI)
# 2      N640EC  3/11/21     EC35        KPGV          Pitt-Greenville (KPGV)
# 3      N640EC  3/10/21     EC35        KIXA              Roanoke Rapids, NC
# 4      N640EC  3/10/21     EC35        KRWI  Rocky Mount-Wilson Rgnl (KRWI)
#
#   destination_code                     destination    departure dep_UTC_time  \
# 0             KRWI  Rocky Mount-Wilson Rgnl (KRWI)  04:29AM EST     09:29:00
# 1             KPGV          Pitt-Greenville (KPGV)  02:17AM EST     07:17:00
# 2             KRWI  Rocky Mount-Wilson Rgnl (KRWI)  01:15AM EST     06:15:00
# 3             KPGV          Pitt-Greenville (KPGV)  11:33PM EST     04:33:00
# 4             KIXA              Roanoke Rapids, NC  08:50PM EST     01:50:00
#
#        arrival arr_UTC_time  duration  distance_mi  \
# 0  04:46AM EST     09:46:00        16    32.296705
# 1  03:47AM EST     08:47:00        89    32.296705
# 2  01:30AM EST     06:30:00        15    32.296705
# 3  12:02AM EST     05:02:00        28    54.850847
# 4  09:31PM EST     02:31:00        41    41.163189
#
#                                                Owner  origin_Latitude  \
# 0  METRO AVIATION INCSHREVEPORT, LA, US(Corporation)        35.635201
# 1  METRO AVIATION INCSHREVEPORT, LA, US(Corporation)        35.856300
# 2  METRO AVIATION INCSHREVEPORT, LA, US(Corporation)        35.635201
# 3  METRO AVIATION INCSHREVEPORT, LA, US(Corporation)        36.403840
# 4  METRO AVIATION INCSHREVEPORT, LA, US(Corporation)        35.856300
#
#    origin_Longitude  destination_Latitude  destination_Longitude  \
# 0        -77.385300             35.856300             -77.891899
# 1        -77.891899             35.635201             -77.385300
# 2        -77.385300             35.856300             -77.891899
# 3        -77.637860             35.635201             -77.385300
# 4        -77.891899             36.413910             -77.628940
#
#                          airport_origin     city_origin origin_state  \
# 0               Pitt Greenville Airport      Greenville           NC
# 1   Rocky Mount Wilson Regional Airport     Rocky Mount           NC
# 2               Pitt Greenville Airport      Greenville           NC
# 3  Halifax-Northampton Regional Airport  Roanoke Rapids           NC
# 4   Rocky Mount Wilson Regional Airport     Rocky Mount           NC
#
#   country_origin                   airport_destination city_destination  \
# 0             US   Rocky Mount Wilson Regional Airport      Rocky Mount
# 1             US               Pitt Greenville Airport       Greenville
# 2             US   Rocky Mount Wilson Regional Airport      Rocky Mount
# 3             US               Pitt Greenville Airport       Greenville
# 4             US  Halifax-Northampton Regional Airport   Roanoke Rapids
#
#   destination_state country_destination departure_shift arrival_shift
# 0                NC                  US           night         night
# 1                NC                  US           night         night
# 2                NC                  US           night         night
# 3                NC                  US           night         night
# 4                NC                  US           night         night

# %%
# convert date to datetime
rw.date = pd.to_datetime(rw.date, format='%m/%d/%y')

# %%
# split ICAO_code
rw['ICAO_origin'] = rw.origin.str.rsplit("(", n = 1, expand = True)[1].str.split(")", n = 1, expand = True)[0]
rw['ICAO_destination'] = rw.destination.str.rsplit("(", n = 1, expand = True)[1].str.split(")", n = 1, expand = True)[0]

# %%
# Split dual ICAO and take the last one
rw.loc[rw.ICAO_origin.str.contains(' / ', na=False), 'ICAO_origin'] = rw.loc[rw.ICAO_origin.str.contains(' / ', na=False), 'ICAO_origin']\
                                                                        .str.split(" / ", expand=True, n=1)[1]

rw.loc[rw.ICAO_destination.str.contains(' / ', na=False), 'ICAO_destination'] = rw.loc[rw.ICAO_destination.str.contains(' / ', na=False), 'ICAO_destination']\
                                                                                  .str.split(" / ", expand=True, n=1)[1]

# %%
# replace null ICAO code by airport code
rw.loc[rw.ICAO_origin.isna(), 'ICAO_origin'] = rw.loc[rw.ICAO_origin.isna(), 'origin_code'] 
rw.loc[rw.ICAO_destination.isna(), 'ICAO_destination'] = rw.loc[rw.ICAO_destination.isna(), 'destination_code']

# %%
# Transform aita code to icao
rw.loc[~rw.ICAO_origin.str.startswith('K', na=False), 'ICAO_origin'] = 'K' + rw.loc[~rw.ICAO_origin.str.startswith('K', na=False), 'ICAO_origin']
rw.loc[~rw.ICAO_destination.str.startswith('K', na=False), 'ICAO_destination'] = 'K' + rw.loc[~rw.ICAO_destination.str.startswith('K', na=False), 'ICAO_destination']

# %%
# extract hour from dep_UTC_time and assign a new variable
rw['dep_UTC_hour'] = pd.to_datetime(rw.dep_UTC_time.astype('str'), format='%H:%M:%S', errors='coerce').dt.hour.astype('str')
rw['arr_UTC_hour'] = pd.to_datetime(rw.arr_UTC_time.astype('str'), format='%H:%M:%S', errors='coerce').dt.hour.astype('str')

# %%
# sort by 'tail_number', 'date', 'dep_UTC_hour'
rw = rw.sort_values(['tail_number', 'date', 'dep_UTC_hour']).reset_index(drop=True)

# %%
# inspect data
rw
# Out:
#       tail_number       date aircraft origin_code  \
# 0          N101AE 2020-12-04      B06        II29
# 1          N101AE 2020-12-04      B06        K2R2
# 2          N101AE 2020-12-05      B06        38II
# 3          N101AE 2020-12-07      B06         07I
# 4          N101AE 2020-12-07      B06        38II
# ...           ...        ...      ...         ...
# 96069        N9NJ 2021-03-10     A139        KN81
# 96070        N9SP 2021-02-26      NaN        KECP
# 96071        N9SP 2021-03-03     B430        KFWQ
# 96072        N9SP 2021-03-03     B430        KAGC
# 96073        N9SP 2021-03-09     B430        KALB
#
#                                          origin destination_code  \
# 0                              Owens Fld (II29)             0IN7
# 1      Hendricks County-Gordon Graham Fld (2R2)             8IN9
# 2                               Greencastle, IN             0IN7
# 3                               Bloomington, IN             KEYE
# 4                            Hampton Fld (38II)             38II
# ...                                         ...              ...
# 96069                      Hammonton Muni (N81)             KTTN
# 96070     Northwest Florida Beaches Intl (KECP)             27FD
# 96071                          Rostraver (KFWQ)             KAGC
# 96072                   Allegheny County (KAGC)             KALB
# 96073                        Albany Intl (KALB)             KSLK
#
#                       destination    departure dep_UTC_time      arrival  \
# 0                Indianapolis, IN  08:04PM EST     01:04:00  08:58PM EST
# 1                Marcidale (8IN9)  10:44PM EST     03:44:00  11:44PM EST
# 2                Indianapolis, IN  01:12PM EST     18:12:00  04:44PM EST
# 3      Eagle Creek Airpark (KEYE)  08:22PM EST     01:22:00  10:37PM EST
# 4                 Greencastle, IN  12:46PM EST     17:46:00  02:00PM EST
# ...                           ...          ...          ...          ...
# 96069       Trenton Mercer (KTTN)  12:44PM EST     17:44:00  01:05PM EST
# 96070             Panama City, FL  04:56PM CST     22:56:00  05:39PM CST
# 96071     Allegheny County (KAGC)  05:53PM EST     22:53:00  05:59PM EST
# 96072          Albany Intl (KALB)  06:30PM EST     23:30:00  08:40PM EST
# 96073      Adirondack Rgnl (KSLK)  02:29PM EST     19:29:00  03:26PM EST
#
#       arr_UTC_time  duration  distance_mi  \
# 0         01:58:00        54    21.173583
# 1         04:44:00        60     8.086743
# 2         21:44:00       212    18.618289
# 3         03:37:00       134    56.379143
# 4         19:00:00        74     7.663635
# ...            ...       ...          ...
# 96069     18:05:00        20    42.134984
# 96070     23:39:00        42     2.576154
# 96071     22:59:00         6    11.266494
# 96072     01:40:00       129   357.967476
# 96073     20:26:00        57   114.822402
#
#                                                 Owner  origin_Latitude  \
# 0       AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.610901
# 1       AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.748100
# 2       AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.650000
# 3       AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.060840
# 4       AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.728611
# ...                                               ...              ...
# 96069  STATE OF NEW JERSEYTRENTON, NJ, US(Government)        39.667500
# 96070     STATE OF NEW YORKALBANY, NY, US(Government)        30.357106
# 96071     STATE OF NEW YORKALBANY, NY, US(Government)        40.209702
# 96072     STATE OF NEW YORKALBANY, NY, US(Government)        40.354401
# 96073     STATE OF NEW YORKALBANY, NY, US(Government)        42.748299
#
#        origin_Longitude  destination_Latitude  destination_Longitude  \
# 0            -86.756104             39.716670             -86.383330
# 1            -86.473801             39.685600             -86.602203
# 2            -86.750000             39.722050             -86.413390
# 3            -86.648100             39.830700             -86.294403
# 4            -86.823056             39.665580             -86.704650
# ...                 ...                   ...                    ...
# 96069        -74.757698             40.276699             -74.813499
# 96070        -85.795414             30.391940             -85.811110
# 96071        -79.831398             40.354401             -79.930199
# 96072        -79.930199             42.748299             -73.801697
# 96073        -73.801697             44.385300             -74.206200
#
#                                         airport_origin   city_origin  \
# 0                                          Owens Field   Greencastle
# 1                 Hendricks County Gordon Graham Field  Indianapolis
# 2                                        Hampton Field   Greencastle
# 3                            Lake Monroe Seaplane Base   Bloomington
# 4                                        Hampton Field   Greencastle
# ...                                                ...           ...
# 96069                      Hammonton Municipal Airport     Hammonton
# 96070  Northwest Florida Beaches International Airport   Panama City
# 96071                                Rostraver Airport   Monongahela
# 96072                         Allegheny County Airport    Pittsburgh
# 96073                     Albany International Airport        Albany
#
#       origin_state country_origin               airport_destination  \
# 0               IN             US       Roto-Whirl/Holiday Heliport
# 1               IN             US                 Marcidale Airport
# 2               IN             US       Roto-Whirl/Holiday Heliport
# 3               IN             US               Eagle Creek Airpark
# 4               IN             US                     Hampton Field
# ...            ...            ...                               ...
# 96069           NJ             US            Trenton Mercer Airport
# 96070           FL             US  Coastal Helicopters Inc Heliport
# 96071           PA             US          Allegheny County Airport
# 96072           PA             US      Albany International Airport
# 96073           NY             US       Adirondack Regional Airport
#
#       city_destination destination_state country_destination departure_shift  \
# 0         Indianapolis                IN                  US           night
# 1                  Amo                IN                  US           night
# 2         Indianapolis                IN                  US             day
# 3         Indianapolis                IN                  US           night
# 4          Greencastle                IN                  US             day
# ...                ...               ...                 ...             ...
# 96069          Trenton                NJ                  US             day
# 96070      Panama City                FL                  US             day
# 96071       Pittsburgh                PA                  US             day
# 96072           Albany                NY                  US             day
# 96073     Saranac Lake                NY                  US             day
#
#       arrival_shift ICAO_origin ICAO_destination dep_UTC_hour arr_UTC_hour
# 0             night       KII29            K0IN7            1            1
# 1             night        K2R2            K8IN9            3            4
# 2               day       K38II            K0IN7           18           21
# 3             night        K07I             KEYE            1            3
# 4               day       K38II            K38II           17           19
# ...             ...         ...              ...          ...          ...
# 96069           day        KN81             KTTN           17           18
# 96070           day        KECP            K27FD           22           23
# 96071           day        KFWQ             KAGC           22           22
# 96072         night        KAGC             KALB           23            1
# 96073           day        KALB             KSLK           19           20
#
# [96074 rows x 32 columns]

# %% [markdown]
# #### METAR data merging for Origin Location
# ---

# %%
# # scrape METAR data for Origin
# from metar_scraper_origin import metar_scraper_origin
# metar_scraper_origin(rw)

# %%
# load data frame
metar_origin = pd.read_csv("..//Datasets/NEW/METAR/RW_METAR_origin.csv")

# %%
# split date and time. Extract only hours  
metar_origin['hour'] = pd.to_datetime(metar_origin.date, format='%d/%m/%Y %H:%M').dt.hour.astype('str')
metar_origin['date'] = pd.to_datetime(metar_origin.date, format='%d/%m/%Y %H:%M').dt.date.astype('str')

# %%
# convert date to string
rw.date = rw.date.astype('str')

# %%
# sort by 'tail_number', 'date', 'hour' and drop duplicates
metar_origin = metar_origin.sort_values(['tail_number', 'date', 'hour']).drop_duplicates(subset=['tail_number', 'ICAO_origin', 'date', 'hour'])\
                           .reset_index(drop=True)

# %%
# inspect data
metar_origin.head()
# Out:
#   tail_number ICAO_origin        date  \
# 0      N101AE        KGPC  2020-12-09
# 1      N101AE        KGPC  2020-12-09
# 2      N101AE        KIND  2020-12-18
# 3      N101AE        KIND  2020-12-19
# 4      N101AE        KIND  2020-12-29
#
#                                                METAR hour
# 0  METAR KGPC 090355Z AUTO 21009KT 10SM CLR 01/M0...    3
# 1  METAR KGPC 090455Z AUTO 22008KT 10SM CLR 01/M0...    4
# 2  METAR KIND 182354Z 15007KT 10SM SCT220 OVC250 ...   23
# 3  METAR KIND 190054Z 16010KT 10SM OVC230 01/M04 ...    0
# 4  METAR KIND 292154Z 11013KT 10SM BKN090 OVC140 ...   21

# %%
# merge by 'tail_number', 'date', 'ICAO_origin', 'dep_UTC_hour'
rw = rw.merge(metar_origin.add_suffix('_origin'), how='left', left_on=['tail_number', 'date', 'ICAO_origin', 'dep_UTC_hour'],
        right_on=['tail_number_origin', 'date_origin', 'ICAO_origin_origin', 'hour_origin'])\
        .drop(['ICAO_origin', 'dep_UTC_hour','tail_number_origin', 'ICAO_origin_origin', 'date_origin', 'hour_origin'], axis=1)

# %%
# check for null values
rw.METAR_origin.isna().sum()
# Out:
# 41750

# %%
# percent of merged metar origin data
print(round(len(rw.loc[rw.METAR_origin.notnull()])/ len(rw) * 100,2), "%")
# Out:
# 56.54 %

# %%
rw.loc[rw.METAR_origin.isna()]
# Out:
#       tail_number        date aircraft origin_code  \
# 0          N101AE  2020-12-04      B06        II29
# 1          N101AE  2020-12-04      B06        K2R2
# 2          N101AE  2020-12-05      B06        38II
# 3          N101AE  2020-12-07      B06         07I
# 4          N101AE  2020-12-07      B06        38II
# ...           ...         ...      ...         ...
# 96057        N9NJ  2021-02-15     A139        KN81
# 96059        N9NJ  2021-02-17     A139        KN81
# 96061        N9NJ  2021-02-23     A139        KN81
# 96069        N9NJ  2021-03-10     A139        KN81
# 96071        N9SP  2021-03-03     B430        KFWQ
#
#                                          origin destination_code  \
# 0                              Owens Fld (II29)             0IN7
# 1      Hendricks County-Gordon Graham Fld (2R2)             8IN9
# 2                               Greencastle, IN             0IN7
# 3                               Bloomington, IN             KEYE
# 4                            Hampton Fld (38II)             38II
# ...                                         ...              ...
# 96057                      Hammonton Muni (N81)             0NJ0
# 96059                      Hammonton Muni (N81)             KMJX
# 96061                      Hammonton Muni (N81)             KTTN
# 96069                      Hammonton Muni (N81)             KTTN
# 96071                          Rostraver (KFWQ)             KAGC
#
#                       destination    departure dep_UTC_time      arrival  \
# 0                Indianapolis, IN  08:04PM EST     01:04:00  08:58PM EST
# 1                Marcidale (8IN9)  10:44PM EST     03:44:00  11:44PM EST
# 2                Indianapolis, IN  01:12PM EST     18:12:00  04:44PM EST
# 3      Eagle Creek Airpark (KEYE)  08:22PM EST     01:22:00  10:37PM EST
# 4                 Greencastle, IN  12:46PM EST     17:46:00  02:00PM EST
# ...                           ...          ...          ...          ...
# 96057           Atlantic City, NJ  03:21PM EST     20:21:00  03:57PM EST
# 96059         Ocean County (KMJX)  04:40PM EST     21:40:00  04:53PM EST
# 96061       Trenton Mercer (KTTN)  03:19PM EST     20:19:00  03:37PM EST
# 96069       Trenton Mercer (KTTN)  12:44PM EST     17:44:00  01:05PM EST
# 96071     Allegheny County (KAGC)  05:53PM EST     22:53:00  05:59PM EST
#
#       arr_UTC_time  duration  distance_mi  \
# 0         01:58:00        54    21.173583
# 1         04:44:00        60     8.086743
# 2         21:44:00       212    18.618289
# 3         03:37:00       134    56.379143
# 4         19:00:00        74     7.663635
# ...            ...       ...          ...
# 96057     20:57:00        36    27.405643
# 96059     21:53:00        12    30.576678
# 96061     20:37:00        17    42.134984
# 96069     18:05:00        20    42.134984
# 96071     22:59:00         6    11.266494
#
#                                                 Owner  origin_Latitude  \
# 0       AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.610901
# 1       AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.748100
# 2       AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.650000
# 3       AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.060840
# 4       AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.728611
# ...                                               ...              ...
# 96057  STATE OF NEW JERSEYTRENTON, NJ, US(Government)        39.667500
# 96059  STATE OF NEW JERSEYTRENTON, NJ, US(Government)        39.667500
# 96061  STATE OF NEW JERSEYTRENTON, NJ, US(Government)        39.667500
# 96069  STATE OF NEW JERSEYTRENTON, NJ, US(Government)        39.667500
# 96071     STATE OF NEW YORKALBANY, NY, US(Government)        40.209702
#
#        origin_Longitude  destination_Latitude  destination_Longitude  \
# 0            -86.756104             39.716670             -86.383330
# 1            -86.473801             39.685600             -86.602203
# 2            -86.750000             39.722050             -86.413390
# 3            -86.648100             39.830700             -86.294403
# 4            -86.823056             39.665580             -86.704650
# ...                 ...                   ...                    ...
# 96057        -74.757698             39.358970             -74.434630
# 96059        -74.757698             39.927502             -74.292397
# 96061        -74.757698             40.276699             -74.813499
# 96069        -74.757698             40.276699             -74.813499
# 96071        -79.831398             40.354401             -79.930199
#
#                              airport_origin   city_origin origin_state  \
# 0                               Owens Field   Greencastle           IN
# 1      Hendricks County Gordon Graham Field  Indianapolis           IN
# 2                             Hampton Field   Greencastle           IN
# 3                 Lake Monroe Seaplane Base   Bloomington           IN
# 4                             Hampton Field   Greencastle           IN
# ...                                     ...           ...          ...
# 96057           Hammonton Municipal Airport     Hammonton           NJ
# 96059           Hammonton Municipal Airport     Hammonton           NJ
# 96061           Hammonton Municipal Airport     Hammonton           NJ
# 96069           Hammonton Municipal Airport     Hammonton           NJ
# 96071                     Rostraver Airport   Monongahela           PA
#
#       country_origin                    airport_destination city_destination  \
# 0                 US            Roto-Whirl/Holiday Heliport     Indianapolis
# 1                 US                      Marcidale Airport              Amo
# 2                 US            Roto-Whirl/Holiday Heliport     Indianapolis
# 3                 US                    Eagle Creek Airpark     Indianapolis
# 4                 US                          Hampton Field      Greencastle
# ...              ...                                    ...              ...
# 96057             US  Atlantic City Medical Center Heliport    Atlantic City
# 96059             US                   Ocean County Airport       Toms River
# 96061             US                 Trenton Mercer Airport          Trenton
# 96069             US                 Trenton Mercer Airport          Trenton
# 96071             US               Allegheny County Airport       Pittsburgh
#
#       destination_state country_destination departure_shift arrival_shift  \
# 0                    IN                  US           night         night
# 1                    IN                  US           night         night
# 2                    IN                  US             day           day
# 3                    IN                  US           night         night
# 4                    IN                  US             day           day
# ...                 ...                 ...             ...           ...
# 96057                NJ                  US             day           day
# 96059                NJ                  US             day           day
# 96061                NJ                  US             day           day
# 96069                NJ                  US             day           day
# 96071                PA                  US             day           day
#
#       ICAO_destination arr_UTC_hour METAR_origin
# 0                K0IN7            1          NaN
# 1                K8IN9            4          NaN
# 2                K0IN7           21          NaN
# 3                 KEYE            3          NaN
# 4                K38II           19          NaN
# ...                ...          ...          ...
# 96057            K0NJ0           20          NaN
# 96059             KMJX           21          NaN
# 96061             KTTN           20          NaN
# 96069             KTTN           18          NaN
# 96071             KAGC           22          NaN
#
# [41750 rows x 31 columns]

# %% [markdown]
# #### METAR data merging for Destination Location
# ---

# %%
# # scrape METAR data for Origin
# from metar_scraper_destination import metar_scraper_destination
# metar_scraper_destination(rw)

# %%
# load data frame
metar_destination = pd.read_csv("../Datasets/NEW/METAR/RW_METAR_destination.csv")

# %%
# split date and time. Extract only hours  
metar_destination['hour'] = pd.to_datetime(metar_destination.date, format='%d/%m/%Y %H:%M').dt.hour.astype('str')
metar_destination['date'] = pd.to_datetime(metar_destination.date, format='%d/%m/%Y %H:%M').dt.date.astype('str')

# %%
# sort by 'tail_number', 'date', 'hour' and drop duplicates
metar_destination = metar_destination.sort_values(['tail_number', 'date', 'hour']).drop_duplicates(subset=['tail_number', 'ICAO_destination', 'date', 'hour'])\
                           .reset_index(drop=True)

# %%
# inspect data
metar_destination.head()
# Out:
#   tail_number ICAO_destination        date  \
# 0      N101AE             KEYE  2020-12-07
# 1      N101AE             KEYE  2020-12-07
# 2      N101AE             KIND  2020-12-18
# 3      N101AE             KIND  2020-12-18
# 4      N101AE             KIND  2020-12-29
#
#                                                METAR hour
# 0  METAR KEYE 070353Z AUTO 36005KT 10SM OVC027 M0...    3
# 1  METAR KEYE 070453Z AUTO 35005KT 10SM OVC030 M0...    4
# 2  METAR KIND 180054Z 27007KT 9SM FEW014 BKN020 O...    0
# 3  METAR KIND 180154Z 28007KT 9SM FEW026 OVC040 M...    1
# 4  METAR KIND 291954Z 11013G19KT 10SM FEW085 BKN1...   19

# %%
# merge by 'tail_number', 'date', 'ICAO_origin', 'arr_UTC_hour'
rw = rw.merge(metar_destination.add_suffix('_destination'), how='left', left_on=['tail_number', 'date', 'ICAO_destination', 'arr_UTC_hour'],
        right_on=['tail_number_destination', 'date_destination', 'ICAO_destination_destination', 'hour_destination'])\
        .drop(['ICAO_destination', 'arr_UTC_hour','tail_number_destination', 'ICAO_destination_destination', 
               'date_destination', 'hour_destination'], axis=1)

# %%
# check for null values
rw.METAR_destination.isna().sum()
# Out:
# 54028

# %%
# percent of merged metar destination data
print(round(len(rw.loc[rw.METAR_destination.notnull()])/ len(rw) * 100,2), "%")
# Out:
# 43.76 %

# %% [markdown]
# #### METAR Decoding
# ---

# %%
# decode metar data
rw = metar_decoder(rw)

# %%
# inspect data
rw.head()
# Out:
#   tail_number        date aircraft origin_code  \
# 0      N101AE  2020-12-04      B06        II29
# 1      N101AE  2020-12-04      B06        K2R2
# 2      N101AE  2020-12-05      B06        38II
# 3      N101AE  2020-12-07      B06         07I
# 4      N101AE  2020-12-07      B06        38II
#
#                                      origin destination_code  \
# 0                          Owens Fld (II29)             0IN7
# 1  Hendricks County-Gordon Graham Fld (2R2)             8IN9
# 2                           Greencastle, IN             0IN7
# 3                           Bloomington, IN             KEYE
# 4                        Hampton Fld (38II)             38II
#
#                   destination    departure dep_UTC_time      arrival  \
# 0            Indianapolis, IN  08:04PM EST     01:04:00  08:58PM EST
# 1            Marcidale (8IN9)  10:44PM EST     03:44:00  11:44PM EST
# 2            Indianapolis, IN  01:12PM EST     18:12:00  04:44PM EST
# 3  Eagle Creek Airpark (KEYE)  08:22PM EST     01:22:00  10:37PM EST
# 4             Greencastle, IN  12:46PM EST     17:46:00  02:00PM EST
#
#   arr_UTC_time  duration  distance_mi  \
# 0     01:58:00        54    21.173583
# 1     04:44:00        60     8.086743
# 2     21:44:00       212    18.618289
# 3     03:37:00       134    56.379143
# 4     19:00:00        74     7.663635
#
#                                            Owner  origin_Latitude  \
# 0  AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.610901
# 1  AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.748100
# 2  AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.650000
# 3  AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.060840
# 4  AIR EVAC EMS INCO FALLON, MO, US(Corporation)        39.728611
#
#    origin_Longitude  destination_Latitude  destination_Longitude  \
# 0        -86.756104              39.71667             -86.383330
# 1        -86.473801              39.68560             -86.602203
# 2        -86.750000              39.72205             -86.413390
# 3        -86.648100              39.83070             -86.294403
# 4        -86.823056              39.66558             -86.704650
#
#                          airport_origin   city_origin origin_state  \
# 0                           Owens Field   Greencastle           IN
# 1  Hendricks County Gordon Graham Field  Indianapolis           IN
# 2                         Hampton Field   Greencastle           IN
# 3             Lake Monroe Seaplane Base   Bloomington           IN
# 4                         Hampton Field   Greencastle           IN
#
#   country_origin          airport_destination city_destination  \
# 0             US  Roto-Whirl/Holiday Heliport     Indianapolis
# 1             US            Marcidale Airport              Amo
# 2             US  Roto-Whirl/Holiday Heliport     Indianapolis
# 3             US          Eagle Creek Airpark     Indianapolis
# 4             US                Hampton Field      Greencastle
#
#   destination_state country_destination departure_shift arrival_shift  \
# 0                IN                  US           night         night
# 1                IN                  US           night         night
# 2                IN                  US             day           day
# 3                IN                  US           night         night
# 4                IN                  US             day           day
#
#   METAR_origin METAR_time_origin report_type_origin temperature_origin  \
# 0          NaN               NaN                NaN                NaN
# 1          NaN               NaN                NaN                NaN
# 2          NaN               NaN                NaN                NaN
# 3          NaN               NaN                NaN                NaN
# 4          NaN               NaN                NaN                NaN
#
#   dew_point_origin wind_origin wind_peak_origin visibility_origin  \
# 0              NaN         NaN              NaN               NaN
# 1              NaN         NaN              NaN               NaN
# 2              NaN         NaN              NaN               NaN
# 3              NaN         NaN              NaN               NaN
# 4              NaN         NaN              NaN               NaN
#
#   pressure_origin press_sea_level_origin sky_origin remarks_origin  \
# 0             NaN                    NaN        NaN            NaN
# 1             NaN                    NaN        NaN            NaN
# 2             NaN                    NaN        NaN            NaN
# 3             NaN                    NaN        NaN            NaN
# 4             NaN                    NaN        NaN            NaN
#
#                                    METAR_destination METAR_time_destination  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3  METAR KEYE 070353Z AUTO 36005KT 10SM OVC027 M0...               03:53:00
# 4                                                NaN                    NaN
#
#                       report_type_destination temperature_destination  \
# 0                                         NaN                     NaN
# 1                                         NaN                     NaN
# 2                                         NaN                     NaN
# 3  routine report, cycle 4 (automatic report)                  30.9 F
# 4                                         NaN                     NaN
#
#   dew_point_destination wind_destination wind_peak_destination  \
# 0                   NaN              NaN                   NaN
# 1                   NaN              NaN                   NaN
# 2                   NaN              NaN                   NaN
# 3                23.0 F     N at 5 knots               missing
# 4                   NaN              NaN                   NaN
#
#   visibility_destination pressure_destination press_sea_level_destination  \
# 0                    NaN                  NaN                         NaN
# 1                    NaN                  NaN                         NaN
# 2                    NaN                  NaN                         NaN
# 3               10 miles            1015.6 mb                   1016.4 mb
# 4                    NaN                  NaN                         NaN
#
#          sky_destination         remarks_destination
# 0                    NaN                         NaN
# 1                    NaN                         NaN
# 2                    NaN                         NaN
# 3  overcast at 2700 feet  Automated station (type 2)
# 4                    NaN                         NaN

# %%
rw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96074 entries, 0 to 96073
# Data columns (total 52 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   tail_number                  96074 non-null  object
#  1   date                         96074 non-null  object
#  2   aircraft                     90671 non-null  object
#  3   origin_code                  96074 non-null  object
#  4   origin                       96074 non-null  object
#  5   destination_code             96074 non-null  object
#  6   destination                  96074 non-null  object
#  7   departure                    96074 non-null  object
#  8   dep_UTC_time                 96074 non-null  object
#  9   arrival                      96074 non-null  object
#  10  arr_UTC_time                 96074 non-null  object
#  11  duration                     96074 non-null  int64
#  12  distance_mi                  96074 non-null  float64
#  13  Owner                        96074 non-null  object
#  14  origin_Latitude              96074 non-null  float64
#  15  origin_Longitude             96074 non-null  float64
#  16  destination_Latitude         96074 non-null  float64
#  17  destination_Longitude        96074 non-null  float64
#  18  airport_origin               96074 non-null  object
#  19  city_origin                  96011 non-null  object
#  20  origin_state                 96034 non-null  object
#  21  country_origin               96074 non-null  object
#  22  airport_destination          96074 non-null  object
#  23  city_destination             96074 non-null  object
#  24  destination_state            96051 non-null  object
#  25  country_destination          96074 non-null  object
#  26  departure_shift              96074 non-null  object
#  27  arrival_shift                96074 non-null  object
#  28  METAR_origin                 54324 non-null  object
#  29  METAR_time_origin            54283 non-null  object
#  30  report_type_origin           54285 non-null  object
#  31  temperature_origin           54091 non-null  object
#  32  dew_point_origin             54041 non-null  object
#  33  wind_origin                  54041 non-null  object
#  34  wind_peak_origin             54041 non-null  object
#  35  visibility_origin            54041 non-null  object
#  36  pressure_origin              54011 non-null  object
#  37  press_sea_level_origin       36533 non-null  object
#  38  sky_origin                   36533 non-null  object
#  39  remarks_origin               36533 non-null  object
#  40  METAR_destination            42046 non-null  object
#  41  METAR_time_destination       42009 non-null  object
#  42  report_type_destination      42009 non-null  object
#  43  temperature_destination      41850 non-null  object
#  44  dew_point_destination        41804 non-null  object
#  45  wind_destination             41804 non-null  object
#  46  wind_peak_destination        41804 non-null  object
#  47  visibility_destination       41804 non-null  object
#  48  pressure_destination         41786 non-null  object
#  49  press_sea_level_destination  28203 non-null  object
#  50  sky_destination              28203 non-null  object
#  51  remarks_destination          28203 non-null  object
# dtypes: float64(5), int64(1), object(46)
# memory usage: 41.3+ MB

# %%
rw.isna().sum()
# Out:
# tail_number                        0
# date                               0
# aircraft                        5403
# origin_code                        0
# origin                             0
# destination_code                   0
# destination                        0
# departure                          0
# dep_UTC_time                       0
# arrival                            0
# arr_UTC_time                       0
# duration                           0
# distance_mi                        0
# Owner                              0
# origin_Latitude                    0
# origin_Longitude                   0
# destination_Latitude               0
# destination_Longitude              0
# airport_origin                     0
# city_origin                       63
# origin_state                      40
# country_origin                     0
# airport_destination                0
# city_destination                   0
# destination_state                 23
# country_destination                0
# departure_shift                    0
# arrival_shift                      0
# METAR_origin                   41750
# METAR_time_origin              41791
# report_type_origin             41789
# temperature_origin             41983
# dew_point_origin               42033
# wind_origin                    42033
# wind_peak_origin               42033
# visibility_origin              42033
# pressure_origin                42063
# press_sea_level_origin         59541
# sky_origin                     59541
# remarks_origin                 59541
# METAR_destination              54028
# METAR_time_destination         54065
# report_type_destination        54065
# temperature_destination        54224
# dew_point_destination          54270
# wind_destination               54270
# wind_peak_destination          54270
# visibility_destination         54270
# pressure_destination           54288
# press_sea_level_destination    67871
# sky_destination                67871
# remarks_destination            67871
# dtype: int64

# %%
# export as csv
rw.to_csv('../Datasets/NEW/RW_with_metar.csv', index=False)
